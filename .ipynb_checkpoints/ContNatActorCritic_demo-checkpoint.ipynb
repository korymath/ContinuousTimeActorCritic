# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import time
import math

# %%
plt.xkcd()  # Yes...

tmax = 3600

t = tmax*np.linspace(0, 1, tmax, endpoint=False)

contSig = np.zeros(tmax)

steps = tmax/4
for i in range(0, tmax, step):
    contSig[i:i+(steps/3)] = 0
    contSig[i+(steps/3):i+(2*steps/3)] = -math.pi
    contSig[i+(2*steps/3):i+steps] = math.pi

# Two subplots, unpack the axes array immediately
plt.figure(figsize=(40,40))
f, (ax1, ax2) = plt.subplots(2, 1, sharey=False)

ax1.plot(t, contSig)
ax1.set_ylim([-4, 4])
ax1.set_xlim(0,tmax)
ax1.set_title('Control Signal')

delay = 25

noise = np.random.normal(0,0.1,tmax)
simEMG = [0] * (tmax+delay)

for i in range(1,tmax):
    if contSig[i] == 0:
        simEMG[i + delay] = 0
    elif contSig[i] == -math.pi:
        simEMG[i + delay] = 1
    elif contSig[i] == math.pi:
        simEMG[i + delay] = -1
        
simEMGdiff = simEMG[0:tmax]+noise

ax2.plot(t, simEMGdiff)
ax2.set_ylim(-1.5, 1.5)
ax2.set_xlim(0,tmax)
ax2.set_title('Simulated Noisy EMG Signal')

# %%
# Implement a learning algorithm to try to fit the signal

# store the variables for plitting after learning
jointAngle = np.zeros(tmax)

# Initialize the state array for the trajectory
# Possible feedback from the simulated arm includes the angle
# (in radians) and angular velocity (in radians per second) of
# each joint, and the Cartesian position of the end effector.

# The continuous state space is composed of joint angles 
# and differential EMG signals
s = np.array([0,0])

# Initialize the learning parameters
gamma = 0.99
lambd = 0.3

x = 0

m = 1

alpha = 0.1/m
alphaV = 0.1/m
alphaW = 0.1/m

stdC = 102 # 1023
r = 0

delta = np.zeros(tmax)

agentMean = np.zeros(tmax)
agentStd = np.zeros(tmax)

# Initialize the weight vectors
# the should be as long as the feature vector x
wU = np.zeros(m)
wS = np.zeros(m)
v = np.zeros(m)
elU = np.zeros(m)
elS = np.zeros(m)
elV = np.zeros(m)

def featurize(s):
    
    x = 0
    
    # use a representation to get a featurized state space
    # break it down into a smaller dimensionality
    
    # simple representation is two states 
    # if the joint angle is less than or equal to zero that is a single state
    # if the joint angle is greater than 0 that is a different state
    if s[0] > 0:
        x = 1
            
    return x

def getReward(newAngle,timeStep):
    # Define the reward function of the system
    # A positive reward of rt = 1.0 was
    # delivered when θw and θe were both within 0.1 radians of
    # their target angles. A reward of rt = −0.5 was delivered
    # in all other cases, in essence penalizing the learning system
    # when the arm’s posture differed from the target posture.
    targetAngle = contSig[timeStep]
    
    absAngleError = np.abs(newAngle-targetAngle)
    
    if absAngleError < 0.1:
        r = 0.1
    else:
        r = -0.5

    return r

def perform(a,s,timeStep):
    
    # take the action and observe the new state and the reward 
    # new state is defined by the new joint angle
    # which is defined by the old joint angle and the new angular velocity
    # which is applied for that time step and the
    # emg signal at that time index 
    
    # Calculate the new angular state of the joint
    # old angle + angular velocity * time (in this case time = 5ms, the period of action selection)
    # this limits the amount of motion of the joint possible in each action selection
    
    newAngle = s[0] + a * 0.0005
    
    if newAngle < -math.pi:
        newAngle = -math.pi
    elif newAngle > math.pi:
        newAngle = math.pi
    
    s = np.array([newAngle,simEMGdiff[timeStep]])
    
    r = getReward(newAngle,timeStep)
    
    return r,s

# process the training samples that are given
for i in range(tmax):
        
    x = featurize(s)
    
    # store joint angles for plotting
    jointAngle[i] = s[0]
    
    agentMean[i] = np.dot(wU,x)
    
    # standard deviation is bounded to be equal to or greater than 1
    agentStd[i] = max(1,np.exp(np.dot(wS,x) + np.log(stdC)))
    
    # get the action from the normal distribution
    a = round(np.random.normal(agentMean[i],agentStd[i]))
    
    # angular velocity commands are sent to joints (simulated servos) 
    # as integers in the range [−1023, 1023] in radians/sec
    
    if a < -1023:
        a = -1023
    elif a > 1023:
        a = 1023
 
    # take action a and observe the reward, r, and the new state, s
    r,s = perform(a,s,i)
                     
    newX = featurize(s)
    
    delta[i] = r + (gamma * np.dot(v,newX)) - np.dot(v,x)
    elV = lambd * elV + x
    v = v + alphaV * delta[i] * elV
    elU = lambd * elU + (alpha - agentMean[i]) * x
    wU = wU + alphaW * delta[i] * elU
    elS = lambd * elS + (np.power((alpha - agentMean[i]),2) / np.power(agentStd[i],2) - 1) * x
    wS = wS + alphaW * delta[i] * elS
    
#     print 'Step: ' + str(i)
#     print 'Joint Angle: ' + str(jointAngle[i]) + ' radians'
#     print 'Target Angle: ' + str(contSig[i]) + ' radians'
#     print 'Agent Mean: ' + str(agentMean[i])
#     print 'Agent Std: ' + str(agentStd[i])
#     print 'Action: ' + str(a) + ' radians per second'
#     print 'New Joint Angle: ' + str(s[0]) + ' radians'
#     print 'Reward: ' + str(r)
#     print 'TD Error: ' + str(delta[i])
#     print '\n'
# Out:
# Step: 0
# Joint Angle: 0.0 radians
# Target Angle: 0.0 radians
# Agent Mean: 0.0
# Agent Std: 102.0
# Action: -118.0 radians per second
# New Joint Angle: -0.059 radians
# Reward: 0.1
# TD Error: 0.1
#
#
# Step: 1
# Joint Angle: -0.059 radians
# Target Angle: 0.0 radians
# Agent Mean: 0.0
# Agent Std: 102.0
# Action: 114.0 radians per second
# New Joint Angle: -0.002 radians
# Reward: 0.1
# TD Error: 0.1
#
#
# Step: 2
# Joint Angle: -0.002 radians
# Target Angle: 0.0 radians
# Agent Mean: 0.0
# Agent Std: 102.0
# Action: 90.0 radians per second
# New Joint Angle: 0.043 radians
# Reward: 0.1
# TD Error: 0.1
#
#
# Step: 3
# Joint Angle: 0.043 radians
# Target Angle: 0.0 radians
# Agent Mean: 0.0
# Agent Std: 102.0
# Action: -33.0 radians per second
# New Joint Angle: 0.0265 radians
# Reward: 0.1
# TD Error: 0.1
#
#
# Step: 4
# Joint Angle: 0.0265 radians
# Target Angle: 0.0 radians
# Agent Mean: 0.001
# Agent Std: 100.985084013
# Action: 152.0 radians per second
# New Joint Angle: 0.1025 radians
# Reward: -0.5
# TD Error: -0.5001
#
#
# Step: 5
# Joint Angle: 0.1025 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.00545129
# Agent Std: 107.768537981
# Action: 16.0 radians per second
# New Joint Angle: 0.1105 radians
# Reward: -0.5
# TD Error: -0.49944987
#
#
# Step: 6
# Joint Angle: 0.1105 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0126509243051
# Agent Std: 115.51602048
# Action: 6.0 radians per second
# New Joint Angle: 0.1135 radians
# Reward: -0.5
# TD Error: -0.498755634681
#
#
# Step: 7
# Joint Angle: 0.1135 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.020426340674
# Agent Std: 123.975359465
# Action: 24.0 radians per second
# New Joint Angle: 0.1255 radians
# Reward: -0.5
# TD Error: -0.498048897946
#
#
# Step: 8
# Joint Angle: 0.1255 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0287534808808
# Agent Std: 133.09454138
# Action: -168.0 radians per second
# New Joint Angle: 0.0415 radians
# Reward: 0.1
# TD Error: 0.102660871538
#
#
# Step: 9
# Joint Angle: 0.0415 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0269167541714
# Agent Std: 131.158246079
# Action: 61.0 radians per second
# New Joint Angle: 0.072 radians
# Reward: 0.1
# TD Error: 0.102514320064
#
#
# Step: 10
# Joint Angle: 0.072 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0250654442774
# Agent Std: 129.251858604
# Action: -10.0 radians per second
# New Joint Angle: 0.067 radians
# Reward: 0.1
# TD Error: 0.102367903064
#
#
# Step: 11
# Joint Angle: 0.067 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0232305758266
# Agent Std: 127.37555901
# Action: -58.0 radians per second
# New Joint Angle: 0.038 radians
# Reward: 0.1
# TD Error: 0.102221672797
#
#
# Step: 12
# Joint Angle: 0.038 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0214212180519
# Agent Std: 125.529034852
# Action: 220.0 radians per second
# New Joint Angle: 0.148 radians
# Reward: -0.5
# TD Error: -0.49792435529
#
#
# Step: 13
# Joint Angle: 0.148 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0301111044775
# Agent Std: 134.78334661
# Action: 220.0 radians per second
# New Joint Angle: 0.258 radians
# Reward: -0.5
# TD Error: -0.497213038982
#
#
# Step: 14
# Joint Angle: 0.258 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0391836399564
# Agent Std: 144.705246596
# Action: 146.0 radians per second
# New Joint Angle: 0.331 radians
# Reward: -0.5
# TD Error: -0.496502735899
#
#
# Step: 15
# Joint Angle: 0.331 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0488120181805
# Agent Std: 155.341784434
# Action: -4.0 radians per second
# New Joint Angle: 0.329 radians
# Reward: -0.5
# TD Error: -0.495793446653
#
#
# Step: 16
# Joint Angle: 0.329 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0590744075419
# Agent Std: 166.743267462
# Action: 296.0 radians per second
# New Joint Angle: 0.477 radians
# Reward: -0.5
# TD Error: -0.495085170414
#
#
# Step: 17
# Joint Angle: 0.477 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0700242642008
# Agent Std: 178.963467688
# Action: 230.0 radians per second
# New Joint Angle: 0.592 radians
# Reward: -0.5
# TD Error: -0.494377905919
#
#
# Step: 18
# Joint Angle: 0.592 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.081710152372
# Agent Std: 192.05985035
# Action: -66.0 radians per second
# New Joint Angle: 0.559 radians
# Reward: -0.5
# TD Error: -0.493671651778
#
#
# Step: 19
# Joint Angle: 0.559 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0941814256923
# Agent Std: 206.09382001
# Action: -392.0 radians per second
# New Joint Angle: 0.363 radians
# Reward: -0.5
# TD Error: -0.492966406564
#
#
# Step: 20
# Joint Angle: 0.363 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.107489954822
# Agent Std: 221.130983526
# Action: 232.0 radians per second
# New Joint Angle: 0.479 radians
# Reward: -0.5
# TD Error: -0.492262168841
#
#
# Step: 21
# Joint Angle: 0.479 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.121690755422
# Agent Std: 237.241430426
# Action: 50.0 radians per second
# New Joint Angle: 0.504 radians
# Reward: -0.5
# TD Error: -0.491558937171
#
#
# Step: 22
# Joint Angle: 0.504 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.136842316757
# Agent Std: 254.500031602
# Action: 197.0 radians per second
# New Joint Angle: 0.6025 radians
# Reward: -0.5
# TD Error: -0.490856710118
#
#
# Step: 23
# Joint Angle: 0.6025 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.153006855673
# Agent Std: 272.986757417
# Action: -468.0 radians per second
# New Joint Angle: 0.3685 radians
# Reward: -0.5
# TD Error: -0.490155486247
#
#
# Step: 24
# Joint Angle: 0.3685 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.170250559525
# Agent Std: 292.787016438
# Action: 197.0 radians per second
# New Joint Angle: 0.467 radians
# Reward: -0.5
# TD Error: -0.489455264124
#
#
# Step: 25
# Joint Angle: 0.467 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.188643836421
# Agent Std: 313.992016097
# Action: -467.0 radians per second
# New Joint Angle: 0.2335 radians
# Reward: -0.5
# TD Error: -0.488756042318
#
#
# Step: 26
# Joint Angle: 0.2335 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.208261578569
# Agent Std: 336.699146643
# Action: 196.0 radians per second
# New Joint Angle: 0.3315 radians
# Reward: -0.5
# TD Error: -0.4880578194
#
#
# Step: 27
# Joint Angle: 0.3315 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.229183440994
# Agent Std: 361.012389855
# Action: -26.0 radians per second
# New Joint Angle: 0.3185 radians
# Reward: -0.5
# TD Error: -0.487360593944
#
#
# Step: 28
# Joint Angle: 0.3185 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.251494136941
# Agent Std: 387.042754074
# Action: -279.0 radians per second
# New Joint Angle: 0.179 radians
# Reward: -0.5
# TD Error: -0.486664364524
#
#
# Step: 29
# Joint Angle: 0.179 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.275283751077
# Agent Std: 414.908737197
# Action: -217.0 radians per second
# New Joint Angle: 0.0705 radians
# Reward: 0.1
# TD Error: 0.114030870282
#
#
# Step: 30
# Joint Angle: 0.0705 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.269332106493
# Agent Std: 408.204581806
# Action: 192.0 radians per second
# New Joint Angle: 0.1665 radians
# Reward: -0.5
# TD Error: -0.486132030961
#
#
# Step: 31
# Joint Angle: 0.1665 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.294898370046
# Agent Std: 437.560880183
# Action: -234.0 radians per second
# New Joint Angle: 0.0495 radians
# Reward: 0.1
# TD Error: 0.114562443369
#
#
# Step: 32
# Joint Angle: 0.0495 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.288566825153
# Agent Std: 430.458018382
# Action: -416.0 radians per second
# New Joint Angle: -0.1585 radians
# Reward: -0.5
# TD Error: 0.939878273578
#
#
# Step: 33
# Joint Angle: -0.1585 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -171.0 radians per second
# New Joint Angle: -0.244 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 34
# Joint Angle: -0.244 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -8.0 radians per second
# New Joint Angle: -0.248 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 35
# Joint Angle: -0.248 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -238.0 radians per second
# New Joint Angle: -0.367 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 36
# Joint Angle: -0.367 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -61.0 radians per second
# New Joint Angle: -0.3975 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 37
# Joint Angle: -0.3975 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -8.0 radians per second
# New Joint Angle: -0.4015 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 38
# Joint Angle: -0.4015 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -180.0 radians per second
# New Joint Angle: -0.4915 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 39
# Joint Angle: -0.4915 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -135.0 radians per second
# New Joint Angle: -0.559 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 40
# Joint Angle: -0.559 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 94.0 radians per second
# New Joint Angle: -0.512 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 41
# Joint Angle: -0.512 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 9.0 radians per second
# New Joint Angle: -0.5075 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 42
# Joint Angle: -0.5075 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 166.0 radians per second
# New Joint Angle: -0.4245 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 43
# Joint Angle: -0.4245 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 168.0 radians per second
# New Joint Angle: -0.3405 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 44
# Joint Angle: -0.3405 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 9.0 radians per second
# New Joint Angle: -0.336 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 45
# Joint Angle: -0.336 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -8.0 radians per second
# New Joint Angle: -0.34 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 46
# Joint Angle: -0.34 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -195.0 radians per second
# New Joint Angle: -0.4375 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 47
# Joint Angle: -0.4375 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -214.0 radians per second
# New Joint Angle: -0.5445 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 48
# Joint Angle: -0.5445 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -16.0 radians per second
# New Joint Angle: -0.5525 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 49
# Joint Angle: -0.5525 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -160.0 radians per second
# New Joint Angle: -0.6325 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 50
# Joint Angle: -0.6325 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 50.0 radians per second
# New Joint Angle: -0.6075 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 51
# Joint Angle: -0.6075 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -88.0 radians per second
# New Joint Angle: -0.6515 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 52
# Joint Angle: -0.6515 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 8.0 radians per second
# New Joint Angle: -0.6475 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 53
# Joint Angle: -0.6475 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -85.0 radians per second
# New Joint Angle: -0.69 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 54
# Joint Angle: -0.69 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -50.0 radians per second
# New Joint Angle: -0.715 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 55
# Joint Angle: -0.715 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -40.0 radians per second
# New Joint Angle: -0.735 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 56
# Joint Angle: -0.735 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 144.0 radians per second
# New Joint Angle: -0.663 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 57
# Joint Angle: -0.663 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -58.0 radians per second
# New Joint Angle: -0.692 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 58
# Joint Angle: -0.692 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -150.0 radians per second
# New Joint Angle: -0.767 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 59
# Joint Angle: -0.767 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 60.0 radians per second
# New Joint Angle: -0.737 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 60
# Joint Angle: -0.737 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -146.0 radians per second
# New Joint Angle: -0.81 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 61
# Joint Angle: -0.81 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 85.0 radians per second
# New Joint Angle: -0.7675 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 62
# Joint Angle: -0.7675 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 132.0 radians per second
# New Joint Angle: -0.7015 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 63
# Joint Angle: -0.7015 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 279.0 radians per second
# New Joint Angle: -0.562 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 64
# Joint Angle: -0.562 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -139.0 radians per second
# New Joint Angle: -0.6315 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 65
# Joint Angle: -0.6315 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 287.0 radians per second
# New Joint Angle: -0.488 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 66
# Joint Angle: -0.488 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 78.0 radians per second
# New Joint Angle: -0.449 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 67
# Joint Angle: -0.449 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 140.0 radians per second
# New Joint Angle: -0.379 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 68
# Joint Angle: -0.379 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 45.0 radians per second
# New Joint Angle: -0.3565 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 69
# Joint Angle: -0.3565 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 65.0 radians per second
# New Joint Angle: -0.324 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 70
# Joint Angle: -0.324 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 112.0 radians per second
# New Joint Angle: -0.268 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 71
# Joint Angle: -0.268 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 25.0 radians per second
# New Joint Angle: -0.2555 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 72
# Joint Angle: -0.2555 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -186.0 radians per second
# New Joint Angle: -0.3485 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 73
# Joint Angle: -0.3485 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 149.0 radians per second
# New Joint Angle: -0.274 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 74
# Joint Angle: -0.274 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 120.0 radians per second
# New Joint Angle: -0.214 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 75
# Joint Angle: -0.214 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 130.0 radians per second
# New Joint Angle: -0.149 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 76
# Joint Angle: -0.149 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -63.0 radians per second
# New Joint Angle: -0.1805 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 77
# Joint Angle: -0.1805 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -30.0 radians per second
# New Joint Angle: -0.1955 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 78
# Joint Angle: -0.1955 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -93.0 radians per second
# New Joint Angle: -0.242 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 79
# Joint Angle: -0.242 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 7.0 radians per second
# New Joint Angle: -0.2385 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 80
# Joint Angle: -0.2385 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 89.0 radians per second
# New Joint Angle: -0.194 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 81
# Joint Angle: -0.194 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -97.0 radians per second
# New Joint Angle: -0.2425 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 82
# Joint Angle: -0.2425 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 1.0 radians per second
# New Joint Angle: -0.242 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 83
# Joint Angle: -0.242 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 109.0 radians per second
# New Joint Angle: -0.1875 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 84
# Joint Angle: -0.1875 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 33.0 radians per second
# New Joint Angle: -0.171 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 85
# Joint Angle: -0.171 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -38.0 radians per second
# New Joint Angle: -0.19 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 86
# Joint Angle: -0.19 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 66.0 radians per second
# New Joint Angle: -0.157 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 87
# Joint Angle: -0.157 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 170.0 radians per second
# New Joint Angle: -0.072 radians
# Reward: 0.1
# TD Error: 0.1
#
#
# Step: 88
# Joint Angle: -0.072 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -82.0 radians per second
# New Joint Angle: -0.113 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 89
# Joint Angle: -0.113 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -20.0 radians per second
# New Joint Angle: -0.123 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 90
# Joint Angle: -0.123 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 88.0 radians per second
# New Joint Angle: -0.079 radians
# Reward: 0.1
# TD Error: 0.1
#
#
# Step: 91
# Joint Angle: -0.079 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -79.0 radians per second
# New Joint Angle: -0.1185 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 92
# Joint Angle: -0.1185 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -66.0 radians per second
# New Joint Angle: -0.1515 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 93
# Joint Angle: -0.1515 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -71.0 radians per second
# New Joint Angle: -0.187 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 94
# Joint Angle: -0.187 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -52.0 radians per second
# New Joint Angle: -0.213 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 95
# Joint Angle: -0.213 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -61.0 radians per second
# New Joint Angle: -0.2435 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 96
# Joint Angle: -0.2435 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 132.0 radians per second
# New Joint Angle: -0.1775 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 97
# Joint Angle: -0.1775 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -118.0 radians per second
# New Joint Angle: -0.2365 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 98
# Joint Angle: -0.2365 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 10.0 radians per second
# New Joint Angle: -0.2315 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 99
# Joint Angle: -0.2315 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -173.0 radians per second
# New Joint Angle: -0.318 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 100
# Joint Angle: -0.318 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 69.0 radians per second
# New Joint Angle: -0.2835 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 101
# Joint Angle: -0.2835 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 129.0 radians per second
# New Joint Angle: -0.219 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 102
# Joint Angle: -0.219 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -13.0 radians per second
# New Joint Angle: -0.2255 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 103
# Joint Angle: -0.2255 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 34.0 radians per second
# New Joint Angle: -0.2085 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 104
# Joint Angle: -0.2085 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 58.0 radians per second
# New Joint Angle: -0.1795 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 105
# Joint Angle: -0.1795 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -49.0 radians per second
# New Joint Angle: -0.204 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 106
# Joint Angle: -0.204 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -5.0 radians per second
# New Joint Angle: -0.2065 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 107
# Joint Angle: -0.2065 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -25.0 radians per second
# New Joint Angle: -0.219 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 108
# Joint Angle: -0.219 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -108.0 radians per second
# New Joint Angle: -0.273 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 109
# Joint Angle: -0.273 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 65.0 radians per second
# New Joint Angle: -0.2405 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 110
# Joint Angle: -0.2405 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -69.0 radians per second
# New Joint Angle: -0.275 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 111
# Joint Angle: -0.275 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 106.0 radians per second
# New Joint Angle: -0.222 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 112
# Joint Angle: -0.222 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 32.0 radians per second
# New Joint Angle: -0.206 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 113
# Joint Angle: -0.206 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 164.0 radians per second
# New Joint Angle: -0.124 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 114
# Joint Angle: -0.124 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 110.0 radians per second
# New Joint Angle: -0.069 radians
# Reward: 0.1
# TD Error: 0.1
#
#
# Step: 115
# Joint Angle: -0.069 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 166.0 radians per second
# New Joint Angle: 0.014 radians
# Reward: 0.1
# TD Error: -1.22285997174
#
#
# Step: 116
# Joint Angle: 0.014 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.248342265811
# Agent Std: 388.073131626
# Action: 69.0 radians per second
# New Joint Angle: 0.0485 radians
# Reward: 0.1
# TD Error: 0.113362221937
#
#
# Step: 117
# Joint Angle: 0.0485 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.244393380486
# Agent Std: 383.698693551
# Action: 881.0 radians per second
# New Joint Angle: 0.489 radians
# Reward: -0.5
# TD Error: -0.486751140285
#
#
# Step: 118
# Joint Angle: 0.489 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.266243447405
# Agent Std: 408.762862511
# Action: 278.0 radians per second
# New Joint Angle: 0.628 radians
# Reward: -0.5
# TD Error: -0.486118363803
#
#
# Step: 119
# Joint Angle: 0.628 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.290593712495
# Agent Std: 437.337666046
# Action: -349.0 radians per second
# New Joint Angle: 0.4535 radians
# Reward: -0.5
# TD Error: -0.485442659277
#
#
# Step: 120
# Joint Angle: 0.4535 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.31684972301
# Agent Std: 468.479693802
# Action: -68.0 radians per second
# New Joint Angle: 0.4195 radians
# Reward: -0.5
# TD Error: -0.484754787029
#
#
# Step: 121
# Joint Angle: 0.4195 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.344922354605
# Agent Std: 501.987444078
# Action: 232.0 radians per second
# New Joint Angle: 0.5355 radians
# Reward: -0.5
# TD Error: -0.484063962982
#
#
# Step: 122
# Joint Angle: 0.5355 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.37486923001
# Agent Std: 537.902133719
# Action: 403.0 radians per second
# New Joint Angle: 0.737 radians
# Reward: -0.5
# TD Error: -0.483372947153
#
#
# Step: 123
# Joint Angle: 0.737 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.406794361535
# Agent Std: 576.349794363
# Action: -642.0 radians per second
# New Joint Angle: 0.416 radians
# Reward: -0.5
# TD Error: -0.482682565391
#
#
# Step: 124
# Joint Angle: 0.416 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.440820302041
# Agent Std: 617.491209545
# Action: -131.0 radians per second
# New Joint Angle: 0.3505 radians
# Reward: -0.5
# TD Error: -0.48199306411
#
#
# Step: 125
# Joint Angle: 0.3505 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.477080666054
# Agent Std: 661.506345808
# Action: 922.0 radians per second
# New Joint Angle: 0.8115 radians
# Reward: -0.5
# TD Error: -0.481304516143
#
#
# Step: 126
# Joint Angle: 0.8115 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.515718388483
# Agent Std: 708.58987676
# Action: 344.0 radians per second
# New Joint Angle: 0.9835 radians
# Reward: -0.5
# TD Error: -0.480616942323
#
#
# Step: 127
# Joint Angle: 0.9835 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.556885615207
# Agent Std: 758.950300957
# Action: -180.0 radians per second
# New Joint Angle: 0.8935 radians
# Reward: -0.5
# TD Error: -0.479930347907
#
#
# Step: 128
# Joint Angle: 0.8935 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.600744074342
# Agent Std: 812.810248735
# Action: 451.0 radians per second
# New Joint Angle: 1.119 radians
# Reward: -0.5
# TD Error: -0.479244733489
#
#
# Step: 129
# Joint Angle: 1.119 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.647465606325
# Agent Std: 870.407207984
# Action: 819.0 radians per second
# New Joint Angle: 1.5285 radians
# Reward: -0.5
# TD Error: -0.478560098264
#
#
# Step: 130
# Joint Angle: 1.5285 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.69723276381
# Agent Std: 931.994423934
# Action: 1023 radians per second
# New Joint Angle: 2.04 radians
# Reward: -0.5
# TD Error: -0.477876441014
#
#
# Step: 131
# Joint Angle: 2.04 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.750239457858
# Agent Std: 997.841896744
# Action: -193.0 radians per second
# New Joint Angle: 1.9435 radians
# Reward: -0.5
# TD Error: -0.477193760393
#
#
# Step: 132
# Joint Angle: 1.9435 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.806691645331
# Agent Std: 1068.23745496
# Action: 0.0 radians per second
# New Joint Angle: 1.9435 radians
# Reward: -0.5
# TD Error: -0.476512055024
#
#
# Step: 133
# Joint Angle: 1.9435 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.866808057698
# Agent Std: 1143.48790054
# Action: 771.0 radians per second
# New Joint Angle: 2.329 radians
# Reward: -0.5
# TD Error: -0.475831323518
#
#
# Step: 134
# Joint Angle: 2.329 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.930820972999
# Agent Std: 1223.92022698
# Action: 1021.0 radians per second
# New Joint Angle: 2.8395 radians
# Reward: -0.5
# TD Error: -0.475151564485
#
#
# Step: 135
# Joint Angle: 2.8395 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.998977033286
# Agent Std: 1309.88291393
# Action: 1023 radians per second
# New Joint Angle: 3.14159265359 radians
# Reward: -0.5
# TD Error: -0.474472776536
#
#
# Step: 136
# Joint Angle: 3.14159265359 radians
# Target Angle: 0.0 radians
# Agent Mean: -1.07153811006
# Agent Std: 1401.74730284
# Action: 25.0 radians per second
# New Joint Angle: 3.14159265359 radians
# Reward: -0.5
# TD Error: -0.473794958283
#
#
# Step: 137
# Joint Angle: 3.14159265359 radians
# Target Angle: 0.0 radians
# Agent Mean: -1.14878222049
# Agent Std: 1499.90905833
# Action: -772.0 radians per second
# New Joint Angle: 2.75559265359 radians
# Reward: -0.5
# TD Error: -0.473118108343
#
#
# Step: 138
# Joint Angle: 2.75559265359 radians
# Target Angle: 0.0 radians
# Agent Mean: -1.23100449719
# Agent Std: 1604.7897204
# Action: 12.0 radians per second
# New Joint Angle: 2.76159265359 radians
# Reward: -0.5
# TD Error: -0.472442225331
#
#
# Step: 139
# Joint Angle: 2.76159265359 radians
# Target Angle: 0.0 radians
# Agent Mean: -1.31851821474
# Agent Std: 1716.83835318
# Action: -1023 radians per second
# New Joint Angle: 2.25009265359 radians
# Reward: -0.5
# TD Error: -0.471767307866
#
#
# Step: 140
# Joint Angle: 2.25009265359 radians
# Target Angle: 0.0 radians
# Agent Mean: -1.41165587606
# Agent Std: 1836.53329573
# Action: 293.0 radians per second
# New Joint Angle: 2.39659265359 radians
# Reward: -0.5
# TD Error: -0.471093354569
#
#
# Step: 141
# Joint Angle: 2.39659265359 radians
# Target Angle: 0.0 radians
# Agent Mean: -1.51077036207
# Agent Std: 1964.3840213
# Action: -506.0 radians per second
# New Joint Angle: 2.14359265359 radians
# Reward: -0.5
# TD Error: -0.470420364063
#
#
# Step: 142
# Joint Angle: 2.14359265359 radians
# Target Angle: 0.0 radians
# Agent Mean: -1.61623614826
# Agent Std: 2100.93311146
# Action: -1023 radians per second
# New Joint Angle: 1.63209265359 radians
# Reward: -0.5
# TD Error: -0.469748334971
#
#
# Step: 143
# Joint Angle: 1.63209265359 radians
# Target Angle: 0.0 radians
# Agent Mean: -1.7284505918
# Agent Std: 2246.75835195
# Action: 260.0 radians per second
# New Joint Angle: 1.76209265359 radians
# Reward: -0.5
# TD Error: -0.469077265921
#
#
# Step: 144
# Joint Angle: 1.76209265359 radians
# Target Angle: 0.0 radians
# Agent Mean: -1.8478352934
# Agent Std: 2402.47495767
# Action: -1023 radians per second
# New Joint Angle: 1.25059265359 radians
# Reward: -0.5
# TD Error: -0.468407155541
#
#
# Step: 145
# Joint Angle: 1.25059265359 radians
# Target Angle: 0.0 radians
# Agent Mean: -1.97483753793
# Agent Std: 2568.73793436
# Action: -1023 radians per second
# New Joint Angle: 0.73909265359 radians
# Reward: -0.5
# TD Error: -0.467738002462
#
#
# Step: 146
# Joint Angle: 0.73909265359 radians
# Target Angle: 0.0 radians
# Agent Mean: -2.1099318183
# Agent Std: 2746.24458536
# Action: -839.0 radians per second
# New Joint Angle: 0.31959265359 radians
# Reward: -0.5
# TD Error: -0.467069805316
#
#
# Step: 147
# Joint Angle: 0.31959265359 radians
# Target Angle: 0.0 radians
# Agent Mean: -2.25362144728
# Agent Std: 2935.73717185
# Action: -1023 radians per second
# New Joint Angle: -0.19190734641 radians
# Reward: -0.5
# TD Error: 2.85974372633
#
#
# Step: 148
# Joint Angle: -0.19190734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 52.0 radians per second
# New Joint Angle: -0.16590734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 149
# Joint Angle: -0.16590734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 37.0 radians per second
# New Joint Angle: -0.14740734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 150
# Joint Angle: -0.14740734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -92.0 radians per second
# New Joint Angle: -0.19340734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 151
# Joint Angle: -0.19340734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 65.0 radians per second
# New Joint Angle: -0.16090734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 152
# Joint Angle: -0.16090734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -14.0 radians per second
# New Joint Angle: -0.16790734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 153
# Joint Angle: -0.16790734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 6.0 radians per second
# New Joint Angle: -0.16490734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 154
# Joint Angle: -0.16490734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 33.0 radians per second
# New Joint Angle: -0.14840734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 155
# Joint Angle: -0.14840734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 84.0 radians per second
# New Joint Angle: -0.10640734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 156
# Joint Angle: -0.10640734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -29.0 radians per second
# New Joint Angle: -0.12090734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 157
# Joint Angle: -0.12090734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -32.0 radians per second
# New Joint Angle: -0.13690734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 158
# Joint Angle: -0.13690734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -40.0 radians per second
# New Joint Angle: -0.15690734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 159
# Joint Angle: -0.15690734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 103.0 radians per second
# New Joint Angle: -0.10540734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 160
# Joint Angle: -0.10540734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -92.0 radians per second
# New Joint Angle: -0.15140734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 161
# Joint Angle: -0.15140734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 4.0 radians per second
# New Joint Angle: -0.14940734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 162
# Joint Angle: -0.14940734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -179.0 radians per second
# New Joint Angle: -0.23890734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 163
# Joint Angle: -0.23890734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -15.0 radians per second
# New Joint Angle: -0.24640734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 164
# Joint Angle: -0.24640734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -26.0 radians per second
# New Joint Angle: -0.25940734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 165
# Joint Angle: -0.25940734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -34.0 radians per second
# New Joint Angle: -0.27640734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 166
# Joint Angle: -0.27640734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 5.0 radians per second
# New Joint Angle: -0.27390734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 167
# Joint Angle: -0.27390734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 7.0 radians per second
# New Joint Angle: -0.27040734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 168
# Joint Angle: -0.27040734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 14.0 radians per second
# New Joint Angle: -0.26340734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 169
# Joint Angle: -0.26340734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 25.0 radians per second
# New Joint Angle: -0.25090734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 170
# Joint Angle: -0.25090734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -38.0 radians per second
# New Joint Angle: -0.26990734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 171
# Joint Angle: -0.26990734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -197.0 radians per second
# New Joint Angle: -0.36840734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 172
# Joint Angle: -0.36840734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -21.0 radians per second
# New Joint Angle: -0.37890734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 173
# Joint Angle: -0.37890734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -51.0 radians per second
# New Joint Angle: -0.40440734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 174
# Joint Angle: -0.40440734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 109.0 radians per second
# New Joint Angle: -0.34990734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 175
# Joint Angle: -0.34990734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -121.0 radians per second
# New Joint Angle: -0.41040734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 176
# Joint Angle: -0.41040734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -56.0 radians per second
# New Joint Angle: -0.43840734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 177
# Joint Angle: -0.43840734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 20.0 radians per second
# New Joint Angle: -0.42840734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 178
# Joint Angle: -0.42840734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -51.0 radians per second
# New Joint Angle: -0.45390734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 179
# Joint Angle: -0.45390734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -92.0 radians per second
# New Joint Angle: -0.49990734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 180
# Joint Angle: -0.49990734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 26.0 radians per second
# New Joint Angle: -0.48690734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 181
# Joint Angle: -0.48690734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -3.0 radians per second
# New Joint Angle: -0.48840734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 182
# Joint Angle: -0.48840734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 70.0 radians per second
# New Joint Angle: -0.45340734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 183
# Joint Angle: -0.45340734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -29.0 radians per second
# New Joint Angle: -0.46790734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 184
# Joint Angle: -0.46790734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -116.0 radians per second
# New Joint Angle: -0.52590734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 185
# Joint Angle: -0.52590734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 24.0 radians per second
# New Joint Angle: -0.51390734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 186
# Joint Angle: -0.51390734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 98.0 radians per second
# New Joint Angle: -0.46490734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 187
# Joint Angle: -0.46490734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 176.0 radians per second
# New Joint Angle: -0.37690734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 188
# Joint Angle: -0.37690734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -72.0 radians per second
# New Joint Angle: -0.41290734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 189
# Joint Angle: -0.41290734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -89.0 radians per second
# New Joint Angle: -0.45740734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 190
# Joint Angle: -0.45740734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 32.0 radians per second
# New Joint Angle: -0.44140734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 191
# Joint Angle: -0.44140734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 129.0 radians per second
# New Joint Angle: -0.37690734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 192
# Joint Angle: -0.37690734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -26.0 radians per second
# New Joint Angle: -0.38990734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 193
# Joint Angle: -0.38990734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -23.0 radians per second
# New Joint Angle: -0.40140734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 194
# Joint Angle: -0.40140734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -47.0 radians per second
# New Joint Angle: -0.42490734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 195
# Joint Angle: -0.42490734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -24.0 radians per second
# New Joint Angle: -0.43690734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 196
# Joint Angle: -0.43690734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -37.0 radians per second
# New Joint Angle: -0.45540734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 197
# Joint Angle: -0.45540734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -112.0 radians per second
# New Joint Angle: -0.51140734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 198
# Joint Angle: -0.51140734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -11.0 radians per second
# New Joint Angle: -0.51690734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 199
# Joint Angle: -0.51690734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 56.0 radians per second
# New Joint Angle: -0.48890734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 200
# Joint Angle: -0.48890734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -128.0 radians per second
# New Joint Angle: -0.55290734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 201
# Joint Angle: -0.55290734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 177.0 radians per second
# New Joint Angle: -0.46440734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 202
# Joint Angle: -0.46440734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -90.0 radians per second
# New Joint Angle: -0.50940734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 203
# Joint Angle: -0.50940734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -150.0 radians per second
# New Joint Angle: -0.58440734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 204
# Joint Angle: -0.58440734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -80.0 radians per second
# New Joint Angle: -0.62440734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 205
# Joint Angle: -0.62440734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 42.0 radians per second
# New Joint Angle: -0.60340734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 206
# Joint Angle: -0.60340734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -40.0 radians per second
# New Joint Angle: -0.62340734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 207
# Joint Angle: -0.62340734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -19.0 radians per second
# New Joint Angle: -0.63290734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 208
# Joint Angle: -0.63290734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -236.0 radians per second
# New Joint Angle: -0.75090734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 209
# Joint Angle: -0.75090734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 122.0 radians per second
# New Joint Angle: -0.68990734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 210
# Joint Angle: -0.68990734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 37.0 radians per second
# New Joint Angle: -0.67140734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 211
# Joint Angle: -0.67140734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -30.0 radians per second
# New Joint Angle: -0.68640734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 212
# Joint Angle: -0.68640734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 134.0 radians per second
# New Joint Angle: -0.61940734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 213
# Joint Angle: -0.61940734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 158.0 radians per second
# New Joint Angle: -0.54040734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 214
# Joint Angle: -0.54040734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -60.0 radians per second
# New Joint Angle: -0.57040734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 215
# Joint Angle: -0.57040734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 184.0 radians per second
# New Joint Angle: -0.47840734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 216
# Joint Angle: -0.47840734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 130.0 radians per second
# New Joint Angle: -0.41340734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 217
# Joint Angle: -0.41340734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -125.0 radians per second
# New Joint Angle: -0.47590734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 218
# Joint Angle: -0.47590734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 14.0 radians per second
# New Joint Angle: -0.46890734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 219
# Joint Angle: -0.46890734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -60.0 radians per second
# New Joint Angle: -0.49890734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 220
# Joint Angle: -0.49890734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -97.0 radians per second
# New Joint Angle: -0.54740734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 221
# Joint Angle: -0.54740734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 64.0 radians per second
# New Joint Angle: -0.51540734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 222
# Joint Angle: -0.51540734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -85.0 radians per second
# New Joint Angle: -0.55790734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 223
# Joint Angle: -0.55790734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 1.0 radians per second
# New Joint Angle: -0.55740734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 224
# Joint Angle: -0.55740734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -68.0 radians per second
# New Joint Angle: -0.59140734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 225
# Joint Angle: -0.59140734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -10.0 radians per second
# New Joint Angle: -0.59640734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 226
# Joint Angle: -0.59640734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 40.0 radians per second
# New Joint Angle: -0.57640734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 227
# Joint Angle: -0.57640734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 6.0 radians per second
# New Joint Angle: -0.57340734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 228
# Joint Angle: -0.57340734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 228.0 radians per second
# New Joint Angle: -0.45940734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 229
# Joint Angle: -0.45940734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 32.0 radians per second
# New Joint Angle: -0.44340734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 230
# Joint Angle: -0.44340734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -3.0 radians per second
# New Joint Angle: -0.44490734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 231
# Joint Angle: -0.44490734641 radians
# Target Angle: 0.0 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 47.0 radians per second
# New Joint Angle: -0.42140734641 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 232
# Joint Angle: -0.42140734641 radians
# Target Angle: 0.0 radians
# ...
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -311.0 radians per second
# New Joint Angle: -3.14159265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3528
# Joint Angle: -3.14159265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -39.0 radians per second
# New Joint Angle: -3.14159265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3529
# Joint Angle: -3.14159265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 76.0 radians per second
# New Joint Angle: -3.10359265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3530
# Joint Angle: -3.10359265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -65.0 radians per second
# New Joint Angle: -3.13609265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3531
# Joint Angle: -3.13609265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 98.0 radians per second
# New Joint Angle: -3.08709265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3532
# Joint Angle: -3.08709265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 87.0 radians per second
# New Joint Angle: -3.04359265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3533
# Joint Angle: -3.04359265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 146.0 radians per second
# New Joint Angle: -2.97059265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3534
# Joint Angle: -2.97059265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 21.0 radians per second
# New Joint Angle: -2.96009265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3535
# Joint Angle: -2.96009265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 31.0 radians per second
# New Joint Angle: -2.94459265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3536
# Joint Angle: -2.94459265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 52.0 radians per second
# New Joint Angle: -2.91859265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3537
# Joint Angle: -2.91859265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -280.0 radians per second
# New Joint Angle: -3.05859265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3538
# Joint Angle: -3.05859265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 16.0 radians per second
# New Joint Angle: -3.05059265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3539
# Joint Angle: -3.05059265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -50.0 radians per second
# New Joint Angle: -3.07559265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3540
# Joint Angle: -3.07559265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -96.0 radians per second
# New Joint Angle: -3.12359265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3541
# Joint Angle: -3.12359265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 183.0 radians per second
# New Joint Angle: -3.03209265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3542
# Joint Angle: -3.03209265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 118.0 radians per second
# New Joint Angle: -2.97309265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3543
# Joint Angle: -2.97309265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 163.0 radians per second
# New Joint Angle: -2.89159265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3544
# Joint Angle: -2.89159265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 96.0 radians per second
# New Joint Angle: -2.84359265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3545
# Joint Angle: -2.84359265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -17.0 radians per second
# New Joint Angle: -2.85209265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3546
# Joint Angle: -2.85209265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 62.0 radians per second
# New Joint Angle: -2.82109265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3547
# Joint Angle: -2.82109265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 21.0 radians per second
# New Joint Angle: -2.81059265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3548
# Joint Angle: -2.81059265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -144.0 radians per second
# New Joint Angle: -2.88259265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3549
# Joint Angle: -2.88259265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 29.0 radians per second
# New Joint Angle: -2.86809265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3550
# Joint Angle: -2.86809265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -5.0 radians per second
# New Joint Angle: -2.87059265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3551
# Joint Angle: -2.87059265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -92.0 radians per second
# New Joint Angle: -2.91659265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3552
# Joint Angle: -2.91659265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -87.0 radians per second
# New Joint Angle: -2.96009265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3553
# Joint Angle: -2.96009265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 52.0 radians per second
# New Joint Angle: -2.93409265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3554
# Joint Angle: -2.93409265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -103.0 radians per second
# New Joint Angle: -2.98559265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3555
# Joint Angle: -2.98559265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 117.0 radians per second
# New Joint Angle: -2.92709265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3556
# Joint Angle: -2.92709265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -127.0 radians per second
# New Joint Angle: -2.99059265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3557
# Joint Angle: -2.99059265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -59.0 radians per second
# New Joint Angle: -3.02009265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3558
# Joint Angle: -3.02009265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -14.0 radians per second
# New Joint Angle: -3.02709265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3559
# Joint Angle: -3.02709265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 92.0 radians per second
# New Joint Angle: -2.98109265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3560
# Joint Angle: -2.98109265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 72.0 radians per second
# New Joint Angle: -2.94509265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3561
# Joint Angle: -2.94509265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 232.0 radians per second
# New Joint Angle: -2.82909265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3562
# Joint Angle: -2.82909265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -154.0 radians per second
# New Joint Angle: -2.90609265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3563
# Joint Angle: -2.90609265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -95.0 radians per second
# New Joint Angle: -2.95359265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3564
# Joint Angle: -2.95359265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 2.0 radians per second
# New Joint Angle: -2.95259265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3565
# Joint Angle: -2.95259265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -25.0 radians per second
# New Joint Angle: -2.96509265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3566
# Joint Angle: -2.96509265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 13.0 radians per second
# New Joint Angle: -2.95859265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3567
# Joint Angle: -2.95859265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -37.0 radians per second
# New Joint Angle: -2.97709265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3568
# Joint Angle: -2.97709265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -138.0 radians per second
# New Joint Angle: -3.04609265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3569
# Joint Angle: -3.04609265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -39.0 radians per second
# New Joint Angle: -3.06559265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3570
# Joint Angle: -3.06559265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 42.0 radians per second
# New Joint Angle: -3.04459265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3571
# Joint Angle: -3.04459265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 83.0 radians per second
# New Joint Angle: -3.00309265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3572
# Joint Angle: -3.00309265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 66.0 radians per second
# New Joint Angle: -2.97009265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3573
# Joint Angle: -2.97009265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -33.0 radians per second
# New Joint Angle: -2.98659265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3574
# Joint Angle: -2.98659265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 49.0 radians per second
# New Joint Angle: -2.96209265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3575
# Joint Angle: -2.96209265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 190.0 radians per second
# New Joint Angle: -2.86709265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3576
# Joint Angle: -2.86709265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 37.0 radians per second
# New Joint Angle: -2.84859265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3577
# Joint Angle: -2.84859265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 119.0 radians per second
# New Joint Angle: -2.78909265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3578
# Joint Angle: -2.78909265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 169.0 radians per second
# New Joint Angle: -2.70459265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3579
# Joint Angle: -2.70459265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 172.0 radians per second
# New Joint Angle: -2.61859265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3580
# Joint Angle: -2.61859265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -124.0 radians per second
# New Joint Angle: -2.68059265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3581
# Joint Angle: -2.68059265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -80.0 radians per second
# New Joint Angle: -2.72059265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3582
# Joint Angle: -2.72059265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -124.0 radians per second
# New Joint Angle: -2.78259265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3583
# Joint Angle: -2.78259265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -39.0 radians per second
# New Joint Angle: -2.80209265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3584
# Joint Angle: -2.80209265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -132.0 radians per second
# New Joint Angle: -2.86809265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3585
# Joint Angle: -2.86809265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -30.0 radians per second
# New Joint Angle: -2.88309265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3586
# Joint Angle: -2.88309265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -116.0 radians per second
# New Joint Angle: -2.94109265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3587
# Joint Angle: -2.94109265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -71.0 radians per second
# New Joint Angle: -2.97659265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3588
# Joint Angle: -2.97659265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -8.0 radians per second
# New Joint Angle: -2.98059265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3589
# Joint Angle: -2.98059265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 130.0 radians per second
# New Joint Angle: -2.91559265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3590
# Joint Angle: -2.91559265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 86.0 radians per second
# New Joint Angle: -2.87259265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3591
# Joint Angle: -2.87259265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 102.0 radians per second
# New Joint Angle: -2.82159265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3592
# Joint Angle: -2.82159265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 209.0 radians per second
# New Joint Angle: -2.71709265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3593
# Joint Angle: -2.71709265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 149.0 radians per second
# New Joint Angle: -2.64259265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3594
# Joint Angle: -2.64259265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -20.0 radians per second
# New Joint Angle: -2.65259265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3595
# Joint Angle: -2.65259265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -214.0 radians per second
# New Joint Angle: -2.75959265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3596
# Joint Angle: -2.75959265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: -153.0 radians per second
# New Joint Angle: -2.83609265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3597
# Joint Angle: -2.83609265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 44.0 radians per second
# New Joint Angle: -2.81409265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3598
# Joint Angle: -2.81409265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 39.0 radians per second
# New Joint Angle: -2.79459265359 radians
# Reward: -0.5
# TD Error: -0.5
#
#
# Step: 3599
# Joint Angle: -2.79459265359 radians
# Target Angle: 3.14159265359 radians
# Agent Mean: -0.0
# Agent Std: 102.0
# Action: 46.0 radians per second
# New Joint Angle: -2.77159265359 radians
# Reward: -0.5
# TD Error: -0.5

# %%
# Visualize the learning    
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(t, contSig)
ax1.set_ylim(-4,4)
ax1.set_title('Target Angle')

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(t, jointAngle)
ax1.set_title('Learned Joint Angle')

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(t, delta)
ax1.set_title('TD Error')

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(t, agentMean)
ax1.set_title('Agent Mean')

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(t, agentStd)
ax1.set_title('Agent Standard Deviation')
