# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.xkcd()  # Yes...

tmax = 900

t = tmax*np.linspace(0, 1, tmax, endpoint=False)

contSig = zeros(tmax)

step = 300
for i in range(0, tmax, step):
    contSig[i:i+100] = 0
    contSig[i+100:i+200] = -1
    contSig[i+200:i+300] = 1

# Two subplots, unpack the axes array immediately
f, (ax1, ax2, ax3) = plt.subplots(3, 1, sharey=False)

plt.figure(figsize(20,10))

ax1.plot(t, contSig)
ax1.set_ylim([-1.5, 1.5])
ax1.set_title('Control Signal')

simEMG = [0] * tmax

for i in range(1,tmax):
    if contSig[i] == 0:
        simEMG[i] = 0
    elif contSig[i] == -1:
        simEMG[i] = 1
    elif contSig[i] == 1:
        simEMG[i] = -1
        
noise = np.random.normal(0,0.1,tmax)

ax2.plot(t, simEMG+noise)
ax2.set_ylim(-1.5, 1.5)
ax2.set_title('Simulated Noisy EMG Signal')

# Implement a learning algorithm to try to fit the signal
learnedSig = zeros(tmax)



ax3.plot(t, contSig)
ax3.plot(t, learnedSig)
ax3.set_ylim(-1.5, 1.5)
ax3.set_title('Trajectory (Target and Learner)')
